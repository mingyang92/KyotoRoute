# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon
import plotly.express as px

# %matplotlib inline

# %%
points = pd.read_csv("D:/KyotoProject/plot/testPoint.csv")

# %%
points_1809 = pd.read_csv("D:/KyotoProject/output/android_1809.csv")

# %%
points.head()
# Out:
#                                 uid     index              aid   uptime  \
# 0  ea82386f4623428f8a242b4e17f318ff  11571002  ARUKUMACHIKYOTO  41:50.0
# 1  ea82386f4623428f8a242b4e17f318ff  11572775  ARUKUMACHIKYOTO  42:59.7
# 2  ea82386f4623428f8a242b4e17f318ff  11577524  ARUKUMACHIKYOTO  45:05.3
# 3  ea82386f4623428f8a242b4e17f318ff  11578406  ARUKUMACHIKYOTO  17:43.6
# 4  ea82386f4623428f8a242b4e17f318ff  11580267  ARUKUMACHIKYOTO  18:25.9
#
#                         pos      cd1    cd2     cd3  year  month  day  hour  \
# 0  (34.9766046,135.6965579)  Android  ja_JP  3.0.50  2018      9    1     0
# 1  (34.9678067,135.6703647)  Android  ja_JP  3.0.50  2018      9    1     1
# 2  (34.9678602,135.6704294)  Android  ja_JP  3.0.50  2018      9    1     4
# 3  (34.9678602,135.6704294)  Android  ja_JP  3.0.50  2018      9    1     5
# 4  (34.9678602,135.6704294)  Android  ja_JP  3.0.50  2018      9    1     6
#
#    minute     second  longitude    latitude
# ...

# %%
points_1809.head()
# Out:
#    Unnamed: 0     index              aid                               uid  \
# 0           0  11569572  ARUKUMACHIKYOTO  e866f6028d614783a7c7bbde2e5bf324
# 1           1  11569573  ARUKUMACHIKYOTO  e35bbe4b6b23490087f8b34e3eeeaab4
# 2           2  11569574  ARUKUMACHIKYOTO  0786227f20db48c29b484bf47d38203f
# 3           4  11569576  ARUKUMACHIKYOTO  8484d5ae1d11447699983b12a6dc0df4
# 4           5  11569577  ARUKUMACHIKYOTO  66acbc093cd94a60ac7cfc4bbba87582
#
#                        uptime                       pos      cd1    cd2  \
# 0  2018-09-01 00:00:00.893739  (34.9985301,135.7270332)  Android  ja_JP
# 1  2018-09-01 00:00:01.160698  (39.7225388,140.1076999)  Android  ja_JP
# 2  2018-09-01 00:00:02.445708  (34.9803916,135.7067892)  Android  ja_JP
# 3  2018-09-01 00:00:04.054839  (35.0519931,135.7698738)  Android  ja_JP
# 4  2018-09-01 00:00:04.730331  (34.9736962,135.7020846)  Android  ja_JP
#
#       cd3  cd4  ... cd9  cd10  year  month  day  hour  minute    second  \
# ...

# %%
#points_test = points[50:200]
points_test = points

# %%
print(len(points_test))
# Out:
# 963

# %%
token = "https://api.mapbox.com/tokens/v2/haomingyang?access_token=sk.eyJ1IjoiaGFvbWluZ3lhbmciLCJhIjoiY2szOGd6OWEwMDhxaTNjcnRxYXl2eXJ1ayJ9.IekZ9PZJeaVKaZqtHGTooQ" # you will need your own token
fig = px.scatter_mapbox(points_test, lat="longitude", lon="latitude", hover_name="index", hover_data=["month", "day", "hour", "minute"],
                        color_discrete_sequence=["fuchsia"], zoom=13, height=400,  color="hour", size = "day", size_max = 10, color_continuous_scale=px.colors.cyclical.IceFire)
fig.update_layout(mapbox_style="open-street-map")
#fig.update_layout(mapbox_style="dark", mapbox_accesstoken=token)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>
#
#
#             <div id="2b0bc427-14f2-49c8-a9e1-80eafaaace91" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2b0bc427-14f2-49c8-a9e1-80eafaaace91")) {
#                     Plotly.newPlot(
#                         '2b0bc427-14f2-49c8-a9e1-80eafaaace91',
# ...

# %%
token = "pk.eyJ1IjoiaGFvbWluZ3lhbmciLCJhIjoiY2szOGd2amIyMDllZzNjcWpqNnF6MjU0YyJ9.2dKHbwUYHrGe_V2bv0RXaQ" # you will need your own token
fig = px.scatter_mapbox(points_test, lat="longitude", lon="latitude", hover_name="index", hover_data=["month", "day", "hour", "minute"],
                        color_discrete_sequence=["fuchsia"], zoom=13, height=800,  color="hour", size = "day", size_max = 10, color_continuous_scale=px.colors.cyclical.IceFire)
#fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(mapbox_style="dark", mapbox_accesstoken=token)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>
#
#
#             <div id="638f953f-efa9-4d3c-89c6-cb46dc20f7fc" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("638f953f-efa9-4d3c-89c6-cb46dc20f7fc")) {
#                     Plotly.newPlot(
#                         '638f953f-efa9-4d3c-89c6-cb46dc20f7fc',
# ...
